# %%
# Test of simple scraper and entity extractor.
import requests
import datetime
# import packages
import pandas as pd
import numpy as np
import requests
from pandas.io.json import json_normalize #special package in pandas
import json
from matplotlib.pyplot import *
# %matplotlib inline

# %%
# NSF awards API is found at: 
# https://www.research.gov/common/webapi/awardapisearch-v1.htm
nsf_awards_json_api = 'http://api.nsf.gov/services/v1/awards.json'
keywords = 'keyword=ai'

# Make the URL request
res = requests.get(nsf_awards_json_api + '?' + keywords)

# Get the awards data
json_response = res.json()["response"]
print(f'type(awards): {type(json_response)}')
awards = json_response["award"]

# Show each award in the list of awards
for award in awards:
    print('----')
    # Print the award info for each awardee
    print(f'agency: {award["agency"]}')
    print(f'awardeeCity: {award["awardeeCity"]}')
    print(f'awardeeName: {award["awardeeName"]}')
    print(f'awardeeStateCode: {award["awardeeStateCode"]}')
    print(f'fundsObligatedAmt: {award["fundsObligatedAmt"]}')
    print(f'id: {award["id"]}')
    print(f'piFirstName: {award["piFirstName"]}')
    print(f'piLastName: {award["piLastName"]}')
    print(f'publicAccessMandate: {award["publicAccessMandate"]}')
    print(f'date: {award["date"]}')
    print(f'title: {award["title"]}')
# Out:
# type(awards): <class 'dict'>
# ----
# agency: NSF
# awardeeCity: ATLANTA
# awardeeName: Georgia Tech Research Corporation
# awardeeStateCode: GA
# fundsObligatedAmt: 800000
# id: 2205152
# piFirstName: Ali
# piLastName: Adibi
# publicAccessMandate: 1
# date: 09/13/2022
# title: SCH: Intelligent Radiology Through Human-Machine Cooperation
# ----
# agency: NSF
# awardeeCity: CORONA
# awardeeName: New York Hall of Science
# awardeeStateCode: NY
# fundsObligatedAmt: 74971
# id: 2230850
# piFirstName: Dorothy
# piLastName: Bennett
# publicAccessMandate: 1
# date: 08/31/2022
# title: Conference on Human-Centered Approaches to Artificial Intelligence Literacy in Informal Learning
# ----
# agency: NSF
# awardeeCity: PITTSBURGH
# awardeeName: Carnegie-Mellon University
# awardeeStateCode: PA
# fundsObligatedAmt: 790631
# id: 2211882
# piFirstName: Tianqi
# piLastName: Chen
# publicAccessMandate: 1
# date: 08/22/2022
# title: CNS: Medium: Ground up Adaptive Learning System for Heterogeneous Environments
# ----
# agency: NSF
# awardeeCity: BOSTON
# awardeeName: Northeastern University
# awardeeStateCode: MA
# fundsObligatedAmt: 299375
# id: 2147220
# piFirstName: Ronald
# piLastName: Sandler
# publicAccessMandate: 1
# date: 07/07/2022
# title: Research Community Development Grant: Summer Training Program to Expand the Al and Data Ethics Research Community
# ----
# agency: NSF
# awardeeCity: SAN BERNARDINO
# awardeeName: University Enterprises Corporation at CSUSB
# awardeeStateCode: CA
# fundsObligatedAmt: 97668
# id: 2142503
# piFirstName: Yunfei
# piLastName: Hou
# publicAccessMandate: 1
# date: 05/26/2022
# title: Collaborative Research: Broadening Inclusive Participation in Artificial Intelligence Undergraduate Education for Social Good Using A Situated Learning Approach
# ----
# agency: NSF
# awardeeCity: FAYETTEVILLE
# awardeeName: Fayetteville State University
# awardeeStateCode: NC
# fundsObligatedAmt: 397055
# id: 2205502
# piFirstName: Sambit
# piLastName: Bhattacharya
# publicAccessMandate: 1
# date: 05/03/2022
# title: Targeted Infusion Project: Exposing Students to the Social Relevance and Trustworthiness of Artificial Intelligence
# ----
# agency: NSF
# awardeeCity: NEW BRUNSWICK
# awardeeName: Rutgers University New Brunswick
# awardeeStateCode: NJ
# fundsObligatedAmt: 20000
# id: 2137245
# piFirstName: Jorge
# piLastName: Ortiz
# publicAccessMandate: 1
# date: 02/16/2022
# title: IUCRC Planning Grant Rutgers University: Center for Standards and Ethics in Artificial Intelligence (CSEAI)
# ----
# agency: NSF
# awardeeCity: Richardson
# awardeeName: University of Texas at Dallas
# awardeeStateCode: TX
# fundsObligatedAmt: 96488
# id: 2146448
# piFirstName: Shuang
# piLastName: Hao
# publicAccessMandate: 1
# date: 01/13/2022
# title: CAREER: Empowering White-box Driven Analytics to Detect AI-synthesized Deceptive Content
# ----
# agency: NSF
# awardeeCity: LOS ANGELES
# awardeeName: OPAL AI INC.
# awardeeStateCode: CA
# fundsObligatedAmt: 276000
# id: 2126752
# piFirstName: Shahrouz
# piLastName: Alimo
# publicAccessMandate: 1
# date: 01/03/2022
# title: SBIR Phase I:  Autonomous Floorplan Reconstruction
# ----
# agency: NSF
# awardeeCity: PITTSBURGH
# awardeeName: Carnegie-Mellon University
# awardeeStateCode: PA
# fundsObligatedAmt: 866000
# id: 2118924
# piFirstName: Nikolas
# piLastName: Martelaro
# publicAccessMandate: 1
# date: 08/12/2021
# title: Supporting Designers in Learning to Co-create with AI for Complex Computational Design Tasks
# ----
# agency: NSF
# awardeeCity: ATLANTA
# awardeeName: Georgia Tech Research Corporation
# awardeeStateCode: GA
# fundsObligatedAmt: 7980446
# id: 2112633
# piFirstName: Sonia
# piLastName: Chernova
# publicAccessMandate: 1
# date: 07/28/2021
# title: AI Institute for Collaborative Assistance and Responsive Interaction for Networked Groups (AI-CARING)
# ----
# agency: NSF
# awardeeCity: MIAMI
# awardeeName: Miami Dade College
# awardeeStateCode: FL
# fundsObligatedAmt: 986535
# id: 2115153
# piFirstName: Antonio
# piLastName: Delgado
# publicAccessMandate: 1
# date: 07/12/2021
# title: Artificial Intelligence For All: A Framework for a College Certificate
# ----
# agency: NSF
# awardeeCity: CLEMSON
# awardeeName: Clemson University
# awardeeStateCode: SC
# fundsObligatedAmt: 146000
# id: 2114920
# piFirstName: Long
# piLastName: Cheng
# publicAccessMandate: 1
# date: 05/27/2021
# title: Collaborative Research: EAGER: SaTC-EDU: Learning Platform and Education Curriculum for Artificial Intelligence-Driven Socially-Relevant Cybersecurity
# ----
# agency: NSF
# awardeeCity: GREENSBORO
# awardeeName: North Carolina Agricultural & Technical State University
# awardeeStateCode: NC
# fundsObligatedAmt: 100000
# id: 2114936
# piFirstName: Xiaohong
# piLastName: Yuan
# publicAccessMandate: 1
# date: 05/27/2021
# title: Collaborative Research: EAGER: SaTC-EDU: Learning Platform and Education Curriculum for Artificial Intelligence-Driven Socially-Relevant Cybersecurity
# ----
# agency: NSF
# awardeeCity: NEW YORK
# awardeeName: New York University
# awardeeStateCode: NY
# fundsObligatedAmt: 299926
# id: 2103936
# piFirstName: Carlos
# piLastName: Fernandez Granda
# publicAccessMandate: 1
# date: 05/24/2021
# title: Elements: Collaborative Research: Community-driven Environment of AI-powered Noise Reduction Services for Materials Discovery from Electron Microscopy Data
# ----
# agency: NSF
# awardeeCity: WEST LAFAYETTE
# awardeeName: Purdue University
# awardeeStateCode: IN
# fundsObligatedAmt: 299934
# id: 2114974
# piFirstName: Jin
# piLastName: Wei-Kocsis
# publicAccessMandate: 1
# date: 04/27/2021
# title: EAGER: SaTC-EDU: Cybersecurity Education in the Age of Artificial Intelligence: A Novel Proactive and Collaborative Learning Paradigm
# ----
# agency: NSF
# awardeeCity: Champaign
# awardeeName: University of Illinois at Urbana-Champaign
# awardeeStateCode: IL
# fundsObligatedAmt: 168670
# id: 2113955
# piFirstName: Colleen
# piLastName: Lewis
# publicAccessMandate: 1
# date: 04/27/2021
# title: Collaborative Research: EAGER: SaTC-EDU: Artificial Intelligence-Enhanced Cybersecurity: Workforce Needs and Barriers to Learning
# ----
# agency: NSF
# awardeeCity: BOULDER
# awardeeName: University of Colorado at Boulder
# awardeeStateCode: CO
# fundsObligatedAmt: 11996931
# id: 2019805
# piFirstName: Sidney
# piLastName: D'Mello
# publicAccessMandate: 1
# date: 08/25/2020
# title: AI Institute:  Institute for Student-AI Teaming
# ----
# agency: NSF
# awardeeCity: PHILADELPHIA
# awardeeName: University of Pennsylvania
# awardeeStateCode: PA
# fundsObligatedAmt: 500000
# id: 2020312
# piFirstName: Konrad
# piLastName: Kording
# publicAccessMandate: 1
# date: 08/25/2020
# title: AI Institute: Planning: From Biological Intelligence to Human Intelligence to Artificial General Intelligence (B2A)
# ----
# agency: NSF
# awardeeCity: LOS ANGELES
# awardeeName: University of California-Los Angeles
# awardeeStateCode: CA
# fundsObligatedAmt: 98280
# id: 2049670
# piFirstName: James
# piLastName: Davis
# publicAccessMandate: 1
# date: 08/21/2020
# title: Workshop:  Aligning AI and U.S. Advanced Manufacturing Competitiveness
# ----
# agency: NSF
# awardeeCity: NOTRE DAME
# awardeeName: University of Notre Dame
# awardeeStateCode: IN
# fundsObligatedAmt: 0
# id: 2008228
# piFirstName: Dong
# piLastName: Wang
# publicAccessMandate: 1
# date: 08/21/2020
# title: CHS: Small: DeepCrowd: A Crowd-assisted Deep Learning-based Disaster Scene Assessment System with Active Human-AI Interactions
# ----
# agency: NSF
# awardeeCity: SALT LAKE CITY
# awardeeName: University of Utah
# awardeeStateCode: UT
# fundsObligatedAmt: 316000
# id: 2041960
# piFirstName: Eliane
# piLastName: Wiese
# publicAccessMandate: 1
# date: 07/29/2020
# title: EAGER: SaTC-EDU: Teaching Security in Undergraduate Artificial Intelligence Courses Using Transparency and Contextualization
# ----
# agency: NSF
# awardeeCity: BERKELEY
# awardeeName: University of California-Berkeley
# awardeeStateCode: CA
# fundsObligatedAmt: 299987
# id: 2039637
# piFirstName: Matthew A.
# piLastName: Cannady
# publicAccessMandate: 1
# date: 07/28/2020
# title: EAGER: SaTC-EDU: A transdisciplinary program for pre-college youth to prepare the future workforce for FATE in AI
# ----
# agency: NSF
# awardeeCity: WASHINGTON
# awardeeName: Digital Promise Global
# awardeeStateCode: DC
# fundsObligatedAmt: 49952
# id: 2040753
# piFirstName: Jeremy
# piLastName: Roschelle
# publicAccessMandate: 1
# date: 07/16/2020
# title: AI and the Future of STEM Learning: Engaging Research and Practitioner Audiences
# ----
# agency: NSF
# awardeeCity: COLUMBUS
# awardeeName: Ohio State University
# awardeeStateCode: OH
# fundsObligatedAmt: 83529
# id: 2024736
# piFirstName: Julie
# piLastName: Martin
# publicAccessMandate: 1
# date: 07/09/2020
# title: Collaborative Research: Research Initiation: Engineering students' outcome expectations for AI careers: An exploratory study

# %%
nsf_awards_json_api = 'http://api.nsf.gov/services/v1/awards.json'
keywords = 'keyword=ai'

# Make the URL request
res = requests.get(nsf_awards_json_api + '?' + keywords)

# Get the awards data
json_response = res.json()["response"]
print(f'type(awards): {type(json_response)}')
awards = json_response["award"]

print(awards)
# Out:
# type(awards): <class 'dict'>
# [{'agency': 'NSF', 'awardeeCity': 'ATLANTA', 'awardeeName': 'Georgia Tech Research Corporation', 'awardeeStateCode': 'GA', 'fundsObligatedAmt': '800000', 'id': '2205152', 'piFirstName': 'Ali', 'piLastName': 'Adibi', 'publicAccessMandate': '1', 'date': '09/13/2022', 'title': 'SCH: Intelligent Radiology Through Human-Machine Cooperation'}, {'agency': 'NSF', 'awardeeCity': 'CORONA', 'awardeeName': 'New York Hall of Science', 'awardeeStateCode': 'NY', 'fundsObligatedAmt': '74971', 'id': '2230850', 'piFirstName': 'Dorothy', 'piLastName': 'Bennett', 'publicAccessMandate': '1', 'date': '08/31/2022', 'title': 'Conference on Human-Centered Approaches to Artificial Intelligence Literacy in Informal Learning'}, {'agency': 'NSF', 'awardeeCity': 'PITTSBURGH', 'awardeeName': 'Carnegie-Mellon University', 'awardeeStateCode': 'PA', 'fundsObligatedAmt': '790631', 'id': '2211882', 'piFirstName': 'Tianqi', 'piLastName': 'Chen', 'publicAccessMandate': '1', 'date': '08/22/2022', 'title': 'CNS: Medium: Ground up Adaptive Learning System for Heterogeneous Environments'}, {'agency': 'NSF', 'awardeeCity': 'BOSTON', 'awardeeName': 'Northeastern University', 'awardeeStateCode': 'MA', 'fundsObligatedAmt': '299375', 'id': '2147220', 'piFirstName': 'Ronald', 'piLastName': 'Sandler', 'publicAccessMandate': '1', 'date': '07/07/2022', 'title': 'Research Community Development Grant: Summer Training Program to Expand the Al and Data Ethics Research Community'}, {'agency': 'NSF', 'awardeeCity': 'SAN BERNARDINO', 'awardeeName': 'University Enterprises Corporation at CSUSB', 'awardeeStateCode': 'CA', 'fundsObligatedAmt': '97668', 'id': '2142503', 'piFirstName': 'Yunfei', 'piLastName': 'Hou', 'publicAccessMandate': '1', 'date': '05/26/2022', 'title': 'Collaborative Research: Broadening Inclusive Participation in Artificial Intelligence Undergraduate Education for Social Good Using A Situated Learning Approach'}, {'agency': 'NSF', 'awardeeCity': 'FAYETTEVILLE', 'awardeeName': 'Fayetteville State University', 'awardeeStateCode': 'NC', 'fundsObligatedAmt': '397055', 'id': '2205502', 'piFirstName': 'Sambit', 'piLastName': 'Bhattacharya', 'publicAccessMandate': '1', 'date': '05/03/2022', 'title': 'Targeted Infusion Project: Exposing Students to the Social Relevance and Trustworthiness of Artificial Intelligence'}, {'agency': 'NSF', 'awardeeCity': 'NEW BRUNSWICK', 'awardeeName': 'Rutgers University New Brunswick', 'awardeeStateCode': 'NJ', 'fundsObligatedAmt': '20000', 'id': '2137245', 'piFirstName': 'Jorge', 'piLastName': 'Ortiz', 'publicAccessMandate': '1', 'date': '02/16/2022', 'title': 'IUCRC Planning Grant Rutgers University: Center for Standards and Ethics in Artificial Intelligence (CSEAI)'}, {'agency': 'NSF', 'awardeeCity': 'Richardson', 'awardeeName': 'University of Texas at Dallas', 'awardeeStateCode': 'TX', 'fundsObligatedAmt': '96488', 'id': '2146448', 'piFirstName': 'Shuang', 'piLastName': 'Hao', 'publicAccessMandate': '1', 'date': '01/13/2022', 'title': 'CAREER: Empowering White-box Driven Analytics to Detect AI-synthesized Deceptive Content'}, {'agency': 'NSF', 'awardeeCity': 'LOS ANGELES', 'awardeeName': 'OPAL AI INC.', 'awardeeStateCode': 'CA', 'fundsObligatedAmt': '276000', 'id': '2126752', 'piFirstName': 'Shahrouz', 'piLastName': 'Alimo', 'publicAccessMandate': '1', 'date': '01/03/2022', 'title': 'SBIR Phase I:  Autonomous Floorplan Reconstruction'}, {'agency': 'NSF', 'awardeeCity': 'PITTSBURGH', 'awardeeName': 'Carnegie-Mellon University', 'awardeeStateCode': 'PA', 'fundsObligatedAmt': '866000', 'id': '2118924', 'piFirstName': 'Nikolas', 'piLastName': 'Martelaro', 'publicAccessMandate': '1', 'date': '08/12/2021', 'title': 'Supporting Designers in Learning to Co-create with AI for Complex Computational Design Tasks'}, {'agency': 'NSF', 'awardeeCity': 'ATLANTA', 'awardeeName': 'Georgia Tech Research Corporation', 'awardeeStateCode': 'GA', 'fundsObligatedAmt': '7980446', 'id': '2112633', 'piFirstName': 'Sonia', 'piLastName': 'Chernova', 'publicAccessMand ...

# %%
#print(awards)
rdf = pd.json_normalize(awards)
rdf
# Out:
#    agency     awardeeCity                                        awardeeName  \
# 0     NSF         ATLANTA                  Georgia Tech Research Corporation
# 1     NSF          CORONA                           New York Hall of Science
# 2     NSF      PITTSBURGH                         Carnegie-Mellon University
# 3     NSF          BOSTON                            Northeastern University
# 4     NSF  SAN BERNARDINO        University Enterprises Corporation at CSUSB
# 5     NSF    FAYETTEVILLE                      Fayetteville State University
# 6     NSF   NEW BRUNSWICK                   Rutgers University New Brunswick
# 7     NSF      Richardson                      University of Texas at Dallas
# 8     NSF     LOS ANGELES                                       OPAL AI INC.
# 9     NSF      PITTSBURGH                         Carnegie-Mellon University
# 10    NSF         ATLANTA                  Georgia Tech Research Corporation
# 11    NSF           MIAMI                                 Miami Dade College
# 12    NSF         CLEMSON                                 Clemson University
# 13    NSF      GREENSBORO  North Carolina Agricultural & Technical State ...
# 14    NSF        NEW YORK                                New York University
# 15    NSF  WEST LAFAYETTE                                  Purdue University
# 16    NSF       Champaign         University of Illinois at Urbana-Champaign
# 17    NSF         BOULDER                  University of Colorado at Boulder
# 18    NSF    PHILADELPHIA                         University of Pennsylvania
# 19    NSF     LOS ANGELES               University of California-Los Angeles
# 20    NSF      NOTRE DAME                           University of Notre Dame
# 21    NSF  SALT LAKE CITY                                 University of Utah
# 22    NSF        BERKELEY                  University of California-Berkeley
# 23    NSF      WASHINGTON                             Digital Promise Global
# 24    NSF        COLUMBUS                              Ohio State University
#
#    awardeeStateCode fundsObligatedAmt       id piFirstName        piLastName  \
# 0                GA            800000  2205152         Ali             Adibi
# 1                NY             74971  2230850     Dorothy           Bennett
# 2                PA            790631  2211882      Tianqi              Chen
# 3                MA            299375  2147220      Ronald           Sandler
# 4                CA             97668  2142503      Yunfei               Hou
# 5                NC            397055  2205502      Sambit      Bhattacharya
# 6                NJ             20000  2137245       Jorge             Ortiz
# 7                TX             96488  2146448      Shuang               Hao
# 8                CA            276000  2126752    Shahrouz             Alimo
# 9                PA            866000  2118924     Nikolas         Martelaro
# 10               GA           7980446  2112633       Sonia          Chernova
# 11               FL            986535  2115153     Antonio           Delgado
# 12               SC            146000  2114920        Long             Cheng
# 13               NC            100000  2114936    Xiaohong              Yuan
# 14               NY            299926  2103936      Carlos  Fernandez Granda
# 15               IN            299934  2114974         Jin        Wei-Kocsis
# 16               IL            168670  2113955     Colleen             Lewis
# 17               CO          11996931  2019805      Sidney           D'Mello
# 18               PA            500000  2020312      Konrad           Kording
# 19               CA             98280  2049670       James             Davis
# 20               IN                 0  2008228        Dong              Wang
# 21               UT            316000  2041960      Eliane             Wiese
# 22               CA            299987  2039637  Matthew A.           Cannady
# 23               DC             49952  2040753      Jeremy         Roschelle
# 24               OH             83529  2024736       Julie            Martin
#
#    publicAccessMandate        date  \
# 0                    1  09/13/2022
# 1                    1  08/31/2022
# 2                    1  08/22/2022
# 3                    1  07/07/2022
# 4                    1  05/26/2022
# 5                    1  05/03/2022
# 6                    1  02/16/2022
# 7                    1  01/13/2022
# 8                    1  01/03/2022
# 9                    1  08/12/2021
# 10                   1  07/28/2021
# 11                   1  07/12/2021
# 12                   1  05/27/2021
# 13                   1  05/27/2021
# 14                   1  05/24/2021
# 15                   1  04/27/2021
# 16                   1  04/27/2021
# 17                   1  08/25/2020
# 18                   1  08/25/2020
# 19                   1  08/21/2020
# 20                   1  08/21/2020
# 21                   1  07/29/2020
# 22                   1  07/28/2020
# 23                   1  07/16/2020
# 24                   1  07/09/2020
#
#                                                 title
# 0   SCH: Intelligent Radiology Through Human-Machi...
# 1   Conference on Human-Centered Approaches to Art...
# 2   CNS: Medium: Ground up Adaptive Learning Syste...
# 3   Research Community Development Grant: Summer T...
# 4   Collaborative Research: Broadening Inclusive P...
# 5   Targeted Infusion Project: Exposing Students t...
# 6   IUCRC Planning Grant Rutgers University: Cente...
# 7   CAREER: Empowering White-box Driven Analytics ...
# 8   SBIR Phase I:  Autonomous Floorplan Reconstruc...
# 9   Supporting Designers in Learning to Co-create ...
# 10  AI Institute for Collaborative Assistance and ...
# 11  Artificial Intelligence For All: A Framework f...
# 12  Collaborative Research: EAGER: SaTC-EDU: Learn...
# 13  Collaborative Research: EAGER: SaTC-EDU: Learn...
# 14  Elements: Collaborative Research: Community-dr...
# 15  EAGER: SaTC-EDU: Cybersecurity Education in th...
# 16  Collaborative Research: EAGER: SaTC-EDU: Artif...
# 17    AI Institute:  Institute for Student-AI Teaming
# 18  AI Institute: Planning: From Biological Intell...
# 19  Workshop:  Aligning AI and U.S. Advanced Manuf...
# 20  CHS: Small: DeepCrowd: A Crowd-assisted Deep L...
# 21  EAGER: SaTC-EDU: Teaching Security in Undergra...
# 22  EAGER: SaTC-EDU: A transdisciplinary program f...
# 23  AI and the Future of STEM Learning: Engaging R...
# 24  Collaborative Research: Research Initiation: E...

# %%
rdf.shape
# Out:
# (25, 11)

# %%
rdf['Date2'] = rdf['date'].apply(lambda x: datetime.datetime.strptime(x, '%m/%d/%Y').strftime('%Y-%m-%d'))
rdf.head()
# Out:
#   agency     awardeeCity                                  awardeeName  \
# 0    NSF         ATLANTA            Georgia Tech Research Corporation
# 1    NSF          CORONA                     New York Hall of Science
# 2    NSF      PITTSBURGH                   Carnegie-Mellon University
# 3    NSF          BOSTON                      Northeastern University
# 4    NSF  SAN BERNARDINO  University Enterprises Corporation at CSUSB
#
#   awardeeStateCode fundsObligatedAmt       id piFirstName piLastName  \
# 0               GA            800000  2205152         Ali      Adibi
# 1               NY             74971  2230850     Dorothy    Bennett
# 2               PA            790631  2211882      Tianqi       Chen
# 3               MA            299375  2147220      Ronald    Sandler
# 4               CA             97668  2142503      Yunfei        Hou
#
#   publicAccessMandate        date  \
# 0                   1  09/13/2022
# 1                   1  08/31/2022
# 2                   1  08/22/2022
# 3                   1  07/07/2022
# 4                   1  05/26/2022
#
#                                                title       Date2
# 0  SCH: Intelligent Radiology Through Human-Machi...  2022-09-13
# 1  Conference on Human-Centered Approaches to Art...  2022-08-31
# 2  CNS: Medium: Ground up Adaptive Learning Syste...  2022-08-22
# 3  Research Community Development Grant: Summer T...  2022-07-07
# 4  Collaborative Research: Broadening Inclusive P...  2022-05-26

# %%
rdf['NAME'] = rdf['piFirstName'] + " " + rdf['piLastName']
rdf.head()
# Out:
#   agency     awardeeCity                                  awardeeName  \
# 0    NSF         ATLANTA            Georgia Tech Research Corporation
# 1    NSF          CORONA                     New York Hall of Science
# 2    NSF      PITTSBURGH                   Carnegie-Mellon University
# 3    NSF          BOSTON                      Northeastern University
# 4    NSF  SAN BERNARDINO  University Enterprises Corporation at CSUSB
#
#   awardeeStateCode fundsObligatedAmt       id piFirstName piLastName  \
# 0               GA            800000  2205152         Ali      Adibi
# 1               NY             74971  2230850     Dorothy    Bennett
# 2               PA            790631  2211882      Tianqi       Chen
# 3               MA            299375  2147220      Ronald    Sandler
# 4               CA             97668  2142503      Yunfei        Hou
#
#   publicAccessMandate        date  \
# 0                   1  09/13/2022
# 1                   1  08/31/2022
# 2                   1  08/22/2022
# 3                   1  07/07/2022
# 4                   1  05/26/2022
#
#                                                title       Date2  \
# 0  SCH: Intelligent Radiology Through Human-Machi...  2022-09-13
# 1  Conference on Human-Centered Approaches to Art...  2022-08-31
# 2  CNS: Medium: Ground up Adaptive Learning Syste...  2022-08-22
# 3  Research Community Development Grant: Summer T...  2022-07-07
# 4  Collaborative Research: Broadening Inclusive P...  2022-05-26
#
#               NAME
# 0        Ali Adibi
# 1  Dorothy Bennett
# 2      Tianqi Chen
# 3   Ronald Sandler
# 4       Yunfei Hou

# %%
#Number of dollars overtime 
#agg_funds = rdf[['fundsObligatedAmt','Date2']].groupby(['Date2']).agg('sum')
#agg_funds
#agg_funds= agg_funds.reset_index()
#agg_funds.columns = ["Date","Total Funds Obligated Amount"]
#agg_funds

# %%
agg_funds2 = rdf[['fundsObligatedAmt','Date2']].groupby(['Date2']).describe()
agg_funds2
agg_funds2= agg_funds2.reset_index()
agg_funds2.columns = ["Date","Count","Unique","Total Funds Obligated Amount","Freq"]
agg_funds2
agg_funds_date = agg_funds2.drop(['Unique', 'Freq'], axis=1)
agg_funds_date
# Out:
#           Date Count Total Funds Obligated Amount
# 0   2020-07-09     1                        83529
# 1   2020-07-16     1                        49952
# 2   2020-07-28     1                       299987
# 3   2020-07-29     1                       316000
# 4   2020-08-21     2                        98280
# 5   2020-08-25     2                     11996931
# 6   2021-04-27     2                       299934
# 7   2021-05-24     1                       299926
# 8   2021-05-27     2                       146000
# 9   2021-07-12     1                       986535
# 10  2021-07-28     1                      7980446
# 11  2021-08-12     1                       866000
# 12  2022-01-03     1                       276000
# 13  2022-01-13     1                        96488
# 14  2022-02-16     1                        20000
# 15  2022-05-03     1                       397055
# 16  2022-05-26     1                        97668
# 17  2022-07-07     1                       299375
# 18  2022-08-22     1                       790631
# 19  2022-08-31     1                        74971
# 20  2022-09-13     1                       800000

# %%
#agg_funds['Total Funds Obligated Amount']=agg_funds['Total Funds Obligated Amount'].astype(float)
#agg_funds.dtypes

agg_funds_date['Total Funds Obligated Amount']=agg_funds_date['Total Funds Obligated Amount'].astype(float)
agg_funds_date.dtypes
# Out:
# Date                             object
# Count                            object
# Total Funds Obligated Amount    float64
# dtype: object

# %%
#finalsorted_date = agg_funds.sort_values(by = ['Total Funds Obligated Amount'], ascending = [True])
#finalsorted_date
final_date = agg_funds_date.sort_values(by = ['Date'], ascending = [True])
final_date
# Out:
#           Date Count  Total Funds Obligated Amount
# 0   2020-07-09     1                  8.352900e+04
# 1   2020-07-16     1                  4.995200e+04
# 2   2020-07-28     1                  2.999870e+05
# 3   2020-07-29     1                  3.160000e+05
# 4   2020-08-21     2                  9.828000e+05
# 5   2020-08-25     2                  1.199693e+13
# 6   2021-04-27     2                  2.999342e+11
# 7   2021-05-24     1                  2.999260e+05
# 8   2021-05-27     2                  1.460001e+11
# 9   2021-07-12     1                  9.865350e+05
# 10  2021-07-28     1                  7.980446e+06
# 11  2021-08-12     1                  8.660000e+05
# 12  2022-01-03     1                  2.760000e+05
# 13  2022-01-13     1                  9.648800e+04
# 14  2022-02-16     1                  2.000000e+04
# 15  2022-05-03     1                  3.970550e+05
# 16  2022-05-26     1                  9.766800e+04
# 17  2022-07-07     1                  2.993750e+05
# 18  2022-08-22     1                  7.906310e+05
# 19  2022-08-31     1                  7.497100e+04
# 20  2022-09-13     1                  8.000000e+05

# %%
#money_overtime = final_date.plot.line(x='Date', y='Total Funds Obligated Amount', title="Money Overtime")

# %%
#agg_awarde = rdf[['awardeeName','fundsObligatedAmt']].groupby(['awardeeName']).agg('sum')
#agg_awarde
#agg_awarde= agg_awarde.reset_index()
#agg_awarde.columns = ["Awardee Name","Total Funds Obligated Amount"]
#agg_awarde

# %%
agg_awarde_school = rdf[['awardeeName','fundsObligatedAmt']].groupby(['awardeeName']).describe()
agg_awarde_school
agg_awarde_school= agg_awarde_school.reset_index()
agg_awarde_school.columns = ["Awardee Name","Count","Unique","Total Funds Obligated Amount","Freq"]
agg_awarde_school
agg_awarde_school = agg_awarde_school.drop(['Unique', 'Freq'], axis=1)
agg_awarde_school
# Out:
#                                          Awardee Name Count  \
# 0                          Carnegie-Mellon University     2
# 1                                  Clemson University     1
# 2                              Digital Promise Global     1
# 3                       Fayetteville State University     1
# 4                   Georgia Tech Research Corporation     2
# 5                                  Miami Dade College     1
# 6                            New York Hall of Science     1
# 7                                 New York University     1
# 8   North Carolina Agricultural & Technical State ...     1
# 9                             Northeastern University     1
# 10                                       OPAL AI INC.     1
# 11                              Ohio State University     1
# 12                                  Purdue University     1
# 13                   Rutgers University New Brunswick     1
# 14        University Enterprises Corporation at CSUSB     1
# 15                  University of California-Berkeley     1
# 16               University of California-Los Angeles     1
# 17                  University of Colorado at Boulder     1
# 18         University of Illinois at Urbana-Champaign     1
# 19                           University of Notre Dame     1
# 20                         University of Pennsylvania     1
# 21                      University of Texas at Dallas     1
# 22                                 University of Utah     1
#
#    Total Funds Obligated Amount
# 0                        790631
# 1                        146000
# 2                         49952
# 3                        397055
# 4                        800000
# 5                        986535
# 6                         74971
# 7                        299926
# 8                        100000
# 9                        299375
# 10                       276000
# 11                        83529
# 12                       299934
# 13                        20000
# 14                        97668
# 15                       299987
# 16                        98280
# 17                     11996931
# 18                       168670
# 19                            0
# 20                       500000
# 21                        96488
# 22                       316000

# %%
agg_awarde_school['Total Funds Obligated Amount']=agg_awarde_school['Total Funds Obligated Amount'].astype(str).astype(float)
agg_awarde_school.dtypes
# Out:
# Awardee Name                     object
# Count                            object
# Total Funds Obligated Amount    float64
# dtype: object

# %%
finalsorted_school = agg_awarde_school.sort_values(by = ['Total Funds Obligated Amount'], ascending = [True])
finalsorted_school
# Out:
#                                          Awardee Name Count  \
# 19                           University of Notre Dame     1
# 13                   Rutgers University New Brunswick     1
# 2                              Digital Promise Global     1
# 6                            New York Hall of Science     1
# 11                              Ohio State University     1
# 21                      University of Texas at Dallas     1
# 14        University Enterprises Corporation at CSUSB     1
# 16               University of California-Los Angeles     1
# 8   North Carolina Agricultural & Technical State ...     1
# 1                                  Clemson University     1
# 18         University of Illinois at Urbana-Champaign     1
# 10                                       OPAL AI INC.     1
# 9                             Northeastern University     1
# 7                                 New York University     1
# 12                                  Purdue University     1
# 15                  University of California-Berkeley     1
# 22                                 University of Utah     1
# 3                       Fayetteville State University     1
# 20                         University of Pennsylvania     1
# 0                          Carnegie-Mellon University     2
# 4                   Georgia Tech Research Corporation     2
# 5                                  Miami Dade College     1
# 17                  University of Colorado at Boulder     1
#
#     Total Funds Obligated Amount
# 19                           0.0
# 13                       20000.0
# 2                        49952.0
# 6                        74971.0
# 11                       83529.0
# 21                       96488.0
# 14                       97668.0
# 16                       98280.0
# 8                       100000.0
# 1                       146000.0
# 18                      168670.0
# 10                      276000.0
# 9                       299375.0
# 7                       299926.0
# 12                      299934.0
# 15                      299987.0
# 22                      316000.0
# 3                       397055.0
# 20                      500000.0
# 0                       790631.0
# 4                       800000.0
# 5                       986535.0
# 17                    11996931.0

# %%
funded_schools = finalsorted_school.plot.bar(x='Awardee Name', y='Total Funds Obligated Amount', title="Funded Institutions")

# %%
#Take a table listing all the researchers and total amount of dollars the researchers 
#received. Most money is at the money.
agg_name = rdf[['NAME','fundsObligatedAmt']].groupby(['NAME']).agg('sum')
agg_name
agg_name= agg_name.reset_index()
agg_name.columns = ["Name","Total Funds Obligated Amount"]
agg_name
# Out:
#                        Name Total Funds Obligated Amount
# 0                 Ali Adibi                       800000
# 1           Antonio Delgado                       986535
# 2   Carlos Fernandez Granda                       299926
# 3             Colleen Lewis                       168670
# 4                 Dong Wang                            0
# 5           Dorothy Bennett                        74971
# 6              Eliane Wiese                       316000
# 7               James Davis                        98280
# 8          Jeremy Roschelle                        49952
# 9            Jin Wei-Kocsis                       299934
# 10              Jorge Ortiz                        20000
# 11             Julie Martin                        83529
# 12           Konrad Kording                       500000
# 13               Long Cheng                       146000
# 14       Matthew A. Cannady                       299987
# 15        Nikolas Martelaro                       866000
# 16           Ronald Sandler                       299375
# 17      Sambit Bhattacharya                       397055
# 18           Shahrouz Alimo                       276000
# 19               Shuang Hao                        96488
# 20           Sidney D'Mello                     11996931
# 21           Sonia Chernova                      7980446
# 22              Tianqi Chen                       790631
# 23            Xiaohong Yuan                       100000
# 24               Yunfei Hou                        97668

# %%
agg_name['Total Funds Obligated Amount']=agg_name['Total Funds Obligated Amount'].astype(str).astype(float)
agg_name.dtypes
# Out:
# Name                             object
# Total Funds Obligated Amount    float64
# dtype: object

# %%
finalsorted_name = agg_name.sort_values(by = ['Total Funds Obligated Amount'], ascending = [True])
finalsorted_name
# Out:
#                        Name  Total Funds Obligated Amount
# 4                 Dong Wang                           0.0
# 10              Jorge Ortiz                       20000.0
# 8          Jeremy Roschelle                       49952.0
# 5           Dorothy Bennett                       74971.0
# 11             Julie Martin                       83529.0
# 19               Shuang Hao                       96488.0
# 24               Yunfei Hou                       97668.0
# 7               James Davis                       98280.0
# 23            Xiaohong Yuan                      100000.0
# 13               Long Cheng                      146000.0
# 3             Colleen Lewis                      168670.0
# 18           Shahrouz Alimo                      276000.0
# 16           Ronald Sandler                      299375.0
# 2   Carlos Fernandez Granda                      299926.0
# 9            Jin Wei-Kocsis                      299934.0
# 14       Matthew A. Cannady                      299987.0
# 6              Eliane Wiese                      316000.0
# 17      Sambit Bhattacharya                      397055.0
# 12           Konrad Kording                      500000.0
# 22              Tianqi Chen                      790631.0
# 0                 Ali Adibi                      800000.0
# 15        Nikolas Martelaro                      866000.0
# 1           Antonio Delgado                      986535.0
# 21           Sonia Chernova                     7980446.0
# 20           Sidney D'Mello                    11996931.0

# %%
name_funds = finalsorted_name.plot.bar(x='Name', y='Total Funds Obligated Amount', title="Researcher Funds")

# %%
#Nested topics (search for ai or machine learning and then do search by deep learning, 
# statistical machine learning, transformers)

# %%
df = rdf.copy(deep=True)
df
# Out:
#    agency     awardeeCity                                        awardeeName  \
# 0     NSF         ATLANTA                  Georgia Tech Research Corporation
# 1     NSF          CORONA                           New York Hall of Science
# 2     NSF      PITTSBURGH                         Carnegie-Mellon University
# 3     NSF          BOSTON                            Northeastern University
# 4     NSF  SAN BERNARDINO        University Enterprises Corporation at CSUSB
# 5     NSF    FAYETTEVILLE                      Fayetteville State University
# 6     NSF   NEW BRUNSWICK                   Rutgers University New Brunswick
# 7     NSF      Richardson                      University of Texas at Dallas
# 8     NSF     LOS ANGELES                                       OPAL AI INC.
# 9     NSF      PITTSBURGH                         Carnegie-Mellon University
# 10    NSF         ATLANTA                  Georgia Tech Research Corporation
# 11    NSF           MIAMI                                 Miami Dade College
# 12    NSF         CLEMSON                                 Clemson University
# 13    NSF      GREENSBORO  North Carolina Agricultural & Technical State ...
# 14    NSF        NEW YORK                                New York University
# 15    NSF  WEST LAFAYETTE                                  Purdue University
# 16    NSF       Champaign         University of Illinois at Urbana-Champaign
# 17    NSF         BOULDER                  University of Colorado at Boulder
# 18    NSF    PHILADELPHIA                         University of Pennsylvania
# 19    NSF     LOS ANGELES               University of California-Los Angeles
# 20    NSF      NOTRE DAME                           University of Notre Dame
# 21    NSF  SALT LAKE CITY                                 University of Utah
# 22    NSF        BERKELEY                  University of California-Berkeley
# 23    NSF      WASHINGTON                             Digital Promise Global
# 24    NSF        COLUMBUS                              Ohio State University
#
#    awardeeStateCode fundsObligatedAmt       id piFirstName        piLastName  \
# 0                GA            800000  2205152         Ali             Adibi
# 1                NY             74971  2230850     Dorothy           Bennett
# 2                PA            790631  2211882      Tianqi              Chen
# 3                MA            299375  2147220      Ronald           Sandler
# 4                CA             97668  2142503      Yunfei               Hou
# 5                NC            397055  2205502      Sambit      Bhattacharya
# 6                NJ             20000  2137245       Jorge             Ortiz
# 7                TX             96488  2146448      Shuang               Hao
# 8                CA            276000  2126752    Shahrouz             Alimo
# 9                PA            866000  2118924     Nikolas         Martelaro
# 10               GA           7980446  2112633       Sonia          Chernova
# 11               FL            986535  2115153     Antonio           Delgado
# 12               SC            146000  2114920        Long             Cheng
# 13               NC            100000  2114936    Xiaohong              Yuan
# 14               NY            299926  2103936      Carlos  Fernandez Granda
# 15               IN            299934  2114974         Jin        Wei-Kocsis
# 16               IL            168670  2113955     Colleen             Lewis
# 17               CO          11996931  2019805      Sidney           D'Mello
# 18               PA            500000  2020312      Konrad           Kording
# 19               CA             98280  2049670       James             Davis
# 20               IN                 0  2008228        Dong              Wang
# 21               UT            316000  2041960      Eliane             Wiese
# 22               CA            299987  2039637  Matthew A.           Cannady
# 23               DC             49952  2040753      Jeremy         Roschelle
# 24               OH             83529  2024736       Julie            Martin
#
#    publicAccessMandate        date  \
# 0                    1  09/13/2022
# 1                    1  08/31/2022
# 2                    1  08/22/2022
# 3                    1  07/07/2022
# 4                    1  05/26/2022
# 5                    1  05/03/2022
# 6                    1  02/16/2022
# 7                    1  01/13/2022
# 8                    1  01/03/2022
# 9                    1  08/12/2021
# 10                   1  07/28/2021
# 11                   1  07/12/2021
# 12                   1  05/27/2021
# 13                   1  05/27/2021
# 14                   1  05/24/2021
# 15                   1  04/27/2021
# 16                   1  04/27/2021
# 17                   1  08/25/2020
# 18                   1  08/25/2020
# 19                   1  08/21/2020
# 20                   1  08/21/2020
# 21                   1  07/29/2020
# 22                   1  07/28/2020
# 23                   1  07/16/2020
# 24                   1  07/09/2020
#
#                                                 title       Date2  \
# 0   SCH: Intelligent Radiology Through Human-Machi...  2022-09-13
# 1   Conference on Human-Centered Approaches to Art...  2022-08-31
# 2   CNS: Medium: Ground up Adaptive Learning Syste...  2022-08-22
# 3   Research Community Development Grant: Summer T...  2022-07-07
# 4   Collaborative Research: Broadening Inclusive P...  2022-05-26
# 5   Targeted Infusion Project: Exposing Students t...  2022-05-03
# 6   IUCRC Planning Grant Rutgers University: Cente...  2022-02-16
# 7   CAREER: Empowering White-box Driven Analytics ...  2022-01-13
# 8   SBIR Phase I:  Autonomous Floorplan Reconstruc...  2022-01-03
# 9   Supporting Designers in Learning to Co-create ...  2021-08-12
# 10  AI Institute for Collaborative Assistance and ...  2021-07-28
# 11  Artificial Intelligence For All: A Framework f...  2021-07-12
# 12  Collaborative Research: EAGER: SaTC-EDU: Learn...  2021-05-27
# 13  Collaborative Research: EAGER: SaTC-EDU: Learn...  2021-05-27
# 14  Elements: Collaborative Research: Community-dr...  2021-05-24
# 15  EAGER: SaTC-EDU: Cybersecurity Education in th...  2021-04-27
# 16  Collaborative Research: EAGER: SaTC-EDU: Artif...  2021-04-27
# 17    AI Institute:  Institute for Student-AI Teaming  2020-08-25
# 18  AI Institute: Planning: From Biological Intell...  2020-08-25
# 19  Workshop:  Aligning AI and U.S. Advanced Manuf...  2020-08-21
# 20  CHS: Small: DeepCrowd: A Crowd-assisted Deep L...  2020-08-21
# 21  EAGER: SaTC-EDU: Teaching Security in Undergra...  2020-07-29
# 22  EAGER: SaTC-EDU: A transdisciplinary program f...  2020-07-28
# 23  AI and the Future of STEM Learning: Engaging R...  2020-07-16
# 24  Collaborative Research: Research Initiation: E...  2020-07-09
#
#                        NAME
# 0                 Ali Adibi
# 1           Dorothy Bennett
# 2               Tianqi Chen
# 3            Ronald Sandler
# 4                Yunfei Hou
# 5       Sambit Bhattacharya
# 6               Jorge Ortiz
# 7                Shuang Hao
# 8            Shahrouz Alimo
# 9         Nikolas Martelaro
# 10           Sonia Chernova
# 11          Antonio Delgado
# 12               Long Cheng
# 13            Xiaohong Yuan
# 14  Carlos Fernandez Granda
# 15           Jin Wei-Kocsis
# 16            Colleen Lewis
# 17           Sidney D'Mello
# 18           Konrad Kording
# 19              James Davis
# 20                Dong Wang
# 21             Eliane Wiese
# 22       Matthew A. Cannady
# 23         Jeremy Roschelle
# 24             Julie Martin

# %%
res_transformers = requests.get(nsf_awards_json_api + '?' + 'keyword=transformers')
json_response_tran = res_transformers.json()["response"]
print(f'type(awards): {type(json_response_tran)}')
awards_tran = json_response_tran["award"]
# Out:
# type(awards): <class 'dict'>

# %%
df_tran = pd.json_normalize(awards_tran)
df_tran
# Out:
#    agency       awardeeCity  \
# 0     NSF         KALAMAZOO
# 1     NSF         PRINCETON
# 2     NSF     STATE COLLEGE
# 3     NSF       GAINESVILLE
# 4     NSF           LINCOLN
# 5     NSF          BROOKLYN
# 6     NSF     STATE COLLEGE
# 7     NSF        BURLINGTON
# 8     NSF        BLACKSBURG
# 9     NSF          Stanford
# 10    NSF         MILWAUKEE
# 11    NSF            Austin
# 12    NSF        Wilmington
# 13    NSF         Cambridge
# 14    NSF          Lawrence
# 15    NSF  GLOUCESTER POINT
# 16    NSF        WASHINGTON
# 17    NSF          NEW YORK
# 18    NSF         Cambridge
# 19    NSF           Seattle
# 20    NSF   COLLEGE STATION
# 21    NSF          La Jolla
# 22    NSF        PITTSBURGH
# 23    NSF        Burlington
# 24    NSF      Santa Monica
#
#                                           awardeeName awardeeStateCode  \
# 0                         Western Michigan University               MI
# 1                                Princeton University               NJ
# 2                          Solid State Ceramics, Inc.               PA
# 3                               University of Florida               FL
# 4                      University of Nebraska-Lincoln               NE
# 5                           HIGHEST Transformers Inc.               NY
# 6                          Solid State Ceramics, Inc.               PA
# 7                        Winchester Technologies, LLC               MA
# 8   Virginia Polytechnic Institute and State Unive...               VA
# 9                                 Stanford University               CA
# 10                  University of Wisconsin-Milwaukee               WI
# 11                      University of Texas at Austin               TX
# 12         University of North Carolina at Wilmington               NC
# 13              Massachusetts Institute of Technology               MA
# 14       University of Kansas Center for Research Inc               KS
# 15  College of William & Mary Virginia Institute o...               VA
# 16                       George Washington University               DC
# 17                                  CUNY City College               NY
# 18  University of Maryland Center for Environmenta...               MD
# 19                           University of Washington               WA
# 20                               Texas A&M University               TX
# 21                 University of California-San Diego               CA
# 22                         Carnegie-Mellon University               PA
# 23  University of Vermont & State Agricultural Col...               VT
# 24               Phraxos Research and Development Inc               CA
#
#    fundsObligatedAmt       id  piFirstName    piLastName publicAccessMandate  \
# 0             199105  2138408        Pablo         Gomez                   1
# 1             194635  2203399        Niraj           Jha                   1
# 2             764749  1632476     Safakcan     Tuncdemir                   1
# 3             200000  1611048         Shuo          Wang                   0
# 4             500000  1554497        Liyan            Qu                   0
# 5             207832  1521233        Qiong            Wu                   0
# 6             224967  1448918     Safakcan     Tuncdemir                   0
# 7             150000  1315213   Nian-xiang           Sun                   0
# 8             270962  9810688         Anbo          Wang                   0
# 9             360000  1808489  Juan Manuel  Rivas-Davila                   1
# 10            452978  1650470         Adel        Nasiri                   1
# 11            350000  1214239        Simon           Lam                   0
# 12                    0527193     Bongkeun          Song                   0
# 13            265000  1609240        David     Perreault                   0
# 14            200000  9623753   J. Michael        Ashley                   0
# 15            277783  1556554  Christopher          Hein                   0
# 16            327246  1610390  Amirhossein       Etemadi                   0
# 17            553114  1556556        Maria     Tzortziou                   0
# 18            341276  1556561      Raleigh          Hood                   0
# 19            499826  2113530         Noah         Smith                   1
# 20            270000  1620058     Jean-Luc      Guermond                   0
# 21            449999  1618477      Zhuowen            Tu                   0
# 22           1219459  1546329       Yiming          Yang                   0
# 23            408000  1254549         Paul         Hines                   0
# 24                    9561627        Jesse     Castaneda                   0
#
#           date                                              title
# 0   02/22/2022  ERI: Multiphysics cosimulation approach for op...
# 1   01/28/2022             CCF: SHF: Small: Transformer synthesis
# 2   09/22/2016  STTR Phase II:  Low Temperature Cofired Multil...
# 3   08/17/2016  High Frequency Transformer Winding Power Loss ...
# 4   01/27/2016  CAREER: Adjustable-Voltage-Ratio Magnetoelectr...
# 5   06/24/2015  STTR Phase I:  Research and Development of Hig...
# 6   12/19/2014  STTR Phase I:  Low Temperature Cofired Multila...
# 7   05/30/2013  SBIR Phase I:  Compact and Power Efficient Int...
# 8   05/05/1999  Optical Fiber Sensor-Based Techniques for On-L...
# 9   08/14/2018  High-Voltage High-Power-Density Power Electron...
# 10  01/19/2017  Phase II I/UCRC University of Wisconsin-Milwau...
# 11  08/17/2012  NeTS: Small: An Efficient Reachability Analysi...
# 12  08/29/2005  Starter Grant: Molecular Detection of Diverse ...
# 13  06/28/2016  Collaborative Research: Advances in High-Frequ...
# 14  06/07/1996  CAREER:  Employing Flow Analyses in Practical ...
# 15  03/15/2016  Collaborative Research: Ecosystems on the Edge...
# 16  07/14/2016  Catastrophic impacts of geomagnetic disturbanc...
# 17  03/15/2016  Collaborative Research: Ecosystems on the Edge...
# 18  03/15/2016  Collaborative Research: Ecosystems on the Edge...
# 19  06/30/2021  NSF-BSF: RI: Small: Efficient Transformers via...
# 20  08/30/2016  Advanced numerical methods for multiphysics Ma...
# 21  06/28/2016  RI: Small: Unraveling and Building Top-Down Ge...
# 22  09/14/2015  BIGDATA: F: Large-Scale Transductive Learning ...
# 23  01/03/2013  CAREER: Harnessing Smart Grid Data to Enable R...
# 24  02/21/1996  SBIR Phase I:  MHz Strip-Line Transformer for ...

# %%
df_tran['Date2'] = df_tran['date'].apply(lambda x: datetime.datetime.strptime(x, '%m/%d/%Y').strftime('%Y-%m-%d'))
df_tran.head()
# Out:
#   agency    awardeeCity                     awardeeName awardeeStateCode  \
# 0    NSF      KALAMAZOO     Western Michigan University               MI
# 1    NSF      PRINCETON            Princeton University               NJ
# 2    NSF  STATE COLLEGE      Solid State Ceramics, Inc.               PA
# 3    NSF    GAINESVILLE           University of Florida               FL
# 4    NSF        LINCOLN  University of Nebraska-Lincoln               NE
#
#   fundsObligatedAmt       id piFirstName piLastName publicAccessMandate  \
# 0            199105  2138408       Pablo      Gomez                   1
# 1            194635  2203399       Niraj        Jha                   1
# 2            764749  1632476    Safakcan  Tuncdemir                   1
# 3            200000  1611048        Shuo       Wang                   0
# 4            500000  1554497       Liyan         Qu                   0
#
#          date                                              title       Date2
# 0  02/22/2022  ERI: Multiphysics cosimulation approach for op...  2022-02-22
# 1  01/28/2022             CCF: SHF: Small: Transformer synthesis  2022-01-28
# 2  09/22/2016  STTR Phase II:  Low Temperature Cofired Multil...  2016-09-22
# 3  08/17/2016  High Frequency Transformer Winding Power Loss ...  2016-08-17
# 4  01/27/2016  CAREER: Adjustable-Voltage-Ratio Magnetoelectr...  2016-01-27

# %%
df_tran['NAME'] = df_tran['piFirstName'] + " " + df_tran['piLastName']
df_tran.head()
# Out:
#   agency    awardeeCity                     awardeeName awardeeStateCode  \
# 0    NSF      KALAMAZOO     Western Michigan University               MI
# 1    NSF      PRINCETON            Princeton University               NJ
# 2    NSF  STATE COLLEGE      Solid State Ceramics, Inc.               PA
# 3    NSF    GAINESVILLE           University of Florida               FL
# 4    NSF        LINCOLN  University of Nebraska-Lincoln               NE
#
#   fundsObligatedAmt       id piFirstName piLastName publicAccessMandate  \
# 0            199105  2138408       Pablo      Gomez                   1
# 1            194635  2203399       Niraj        Jha                   1
# 2            764749  1632476    Safakcan  Tuncdemir                   1
# 3            200000  1611048        Shuo       Wang                   0
# 4            500000  1554497       Liyan         Qu                   0
#
#          date                                              title       Date2  \
# 0  02/22/2022  ERI: Multiphysics cosimulation approach for op...  2022-02-22
# 1  01/28/2022             CCF: SHF: Small: Transformer synthesis  2022-01-28
# 2  09/22/2016  STTR Phase II:  Low Temperature Cofired Multil...  2016-09-22
# 3  08/17/2016  High Frequency Transformer Winding Power Loss ...  2016-08-17
# 4  01/27/2016  CAREER: Adjustable-Voltage-Ratio Magnetoelectr...  2016-01-27
#
#                  NAME
# 0         Pablo Gomez
# 1           Niraj Jha
# 2  Safakcan Tuncdemir
# 3           Shuo Wang
# 4            Liyan Qu

# %%
df_tran.dtypes
# Out:
# agency                 object
# awardeeCity            object
# awardeeName            object
# awardeeStateCode       object
# fundsObligatedAmt      object
# id                     object
# piFirstName            object
# piLastName             object
# publicAccessMandate    object
# date                   object
# title                  object
# Date2                  object
# NAME                   object
# dtype: object

# %%
df.dtypes
# Out:
# agency                 object
# awardeeCity            object
# awardeeName            object
# awardeeStateCode       object
# fundsObligatedAmt      object
# id                     object
# piFirstName            object
# piLastName             object
# publicAccessMandate    object
# date                   object
# title                  object
# Date2                  object
# NAME                   object
# dtype: object

# %%
common=df.merge(df_tran, how = 'inner' ,indicator=False)
common
# Out:
# Empty DataFrame
# Columns: [agency, awardeeCity, awardeeName, awardeeStateCode, fundsObligatedAmt, id, piFirstName, piLastName, publicAccessMandate, date, title, Date2, NAME]
# Index: []

# %%
#as shown above, 0 matches between AI and transformers, but transformers is a nested topic of AI
